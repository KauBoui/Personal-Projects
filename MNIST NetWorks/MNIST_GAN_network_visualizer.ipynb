# %%
import numpy
import tensorflow
from tensorflow.keras.models import load_model
from numpy.random import randn
from matplotlib import pyplot as plt

# %%
def latent_points(shape, n):
    X = randn(n * shape)
    X = X.reshape(n, shape)
    return X 

def save_plot(examples, n):
    for i in range(n * n):
        plt.subplot(n,n, 1 + i)
        plt.axis('off')
        plt.imshow(examples[i,:,:,0], cmap='gray_r')
    plt.show()

# %%
model = load_model('/Users/erb/Desktop/CS/Personal-Projects/Personal-Projects/generator_model_003.h5')
latent_points = latent_points(256, 25)
X = model.predict(latent_points)
save_plot(X,5)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
model2 = load_model('/Users/erb/Desktop/CS/Personal-Projects/Personal-Projects/MNIST_GAN_generator_model_020.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
X2 = model2.predict(latent_points)
save_plot(X2,5)

# %%
model3 = load_model('/Users/erb/Desktop/CS/Personal-Projects/Personal-Projects/MNIST_GAN_generator_model_010.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
X3 = model3.predict(latent_points)
save_plot(X3,5)

# %%
model4 = load_model('/Users/erb/Desktop/CS/Personal-Projects/Personal-Projects/MNIST_GAN_generator_model_100.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-87-328499e53c7a> in <module>
# ----> 1 model4 = load_model('/Users/erb/Desktop/CS/Personal-Projects/Personal-Projects/MNIST_GAN_generator_model_100.h5')
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     187       filepath = str(filepath)
#     188     if isinstance(filepath, six.string_types):
# --> 189       loader_impl.parse_saved_model(filepath)
#     190       return saved_model_load.load(filepath, compile)
#     191
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     111                   (export_dir,
#     112                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 113                    constants.SAVED_MODEL_FILENAME_PB))
#     114
# ...

# %%
X4 = model4.predict(latent_points)
save_plot(X4,5)
